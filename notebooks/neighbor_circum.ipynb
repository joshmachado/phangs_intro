# %%
from astropy.table import Table
import pandas as pd
from os import listdir
import re
import numpy as np

# %%
#Location of Circumcloud Tables
circum_fp = '/data/kant/0/sun.1608/PHANGS/mega-tables/v2p0beta/circumcloud/'

# %%
sources = pd.read_csv('/home/machado.35/projects/intro/scripts/sources.csv')
sources = list(sources['sources'])
res = [60,90,120,150]

# %%
circum_tables = listdir(circum_fp)

# %%
for k in range(len(res)):
    for i in range(len(sources)):
        for ii in range(len(circum_tables)):
# Out:
# 'ESO097-013_circumcloud_stats_500pc_116mK_150pc.fits'

# %%
circ_tab = Table.read(circum_fp+'NGC3621_circumcloud_stats_500pc_193mK_60pc.fits')
cat = pd.read_csv('/home/machado.35/projects/intro/sources/ngc3621/ngc3621_60pc_cloud_stats.csv')

# %%
circ_tab
# Out:
# <Table length=525>
#   REGION        RA            DEC       ...   P_DE_L08    P_DE_S20
#                deg            deg       ...   K / cm3     K / cm3
#   bytes9     float64        float64     ...   float64     float64
# --------- -------------- -------------- ... ----------- -----------
#   CLOUD#1      169.55466      -32.78849 ...   3.650e+04         nan
#   CLOUD#2      169.56035      -32.78750 ...   4.832e+04         nan
#   CLOUD#3      169.56003      -32.78826 ...   5.954e+04         nan
#   CLOUD#4      169.56000      -32.78629 ...   3.136e+04         nan
#   CLOUD#5      169.55895      -32.78639 ...   3.458e+04         nan
#   CLOUD#6      169.55522      -32.78418 ...   1.590e+04         nan
#   CLOUD#7      169.55519      -32.77895 ...   1.090e+04         nan
#   CLOUD#8      169.55672      -32.77737 ...   1.159e+04         nan
#   CLOUD#9      169.55652      -32.78781 ...   4.494e+04         nan
#       ...            ...            ... ...         ...         ...
# ...

# %%
cat
# Out:
#      Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  cloudnum  RGAL_KPC           x  \
# 0             0             0               0         1  3.153282  169.558833
# 1             1             1               1         2  3.500246  169.554781
# 2             2             2               2         3  3.440357  169.554650
# 3             3             3               3         4  3.220800  169.558569
# 4             4             4               4         5  3.210247  169.560460
# ..          ...           ...             ...       ...       ...         ...
# 476         476           476             476       477  3.513892  169.579606
# 477         477           477             477       478  3.323676  169.579608
# 478         478           478             478       479  3.223174  169.579167
# 479         479           479             479       480  3.411194  169.578524
# 480         480           480             480       481  3.314091  169.578124
#
# ...
